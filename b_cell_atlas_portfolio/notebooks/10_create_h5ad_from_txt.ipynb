# %%
import os
from pathlib import Path

DATA_ROOT = Path(os.environ.get('B_CELL_ATLAS_DATA', 'data'))

# !ls

# %%
import anndata as ad
import os
import gc 
import scanpy as sc
import pandas as pd

# %%
import scanpy as sc
import pandas as pd
import gzip

# Read the gzipped txt file
with gzip.open(str(DATA_ROOT / 'GSE147766/GSM6058206_NB37.count.csv.gz'), 'rt') as f:
    data = pd.read_csv(f, sep=',', index_col=0)

# Keep data as is (no transpose needed)
adata = sc.AnnData(data)

# Now you'll have:
# - 23,686 genes (observations in adata.obs)
# - 307 cells (variables in adata.var)
print(f"Number of genes: {adata.n_obs}")
print(f"Number of cells: {adata.n_vars}")

# %%
adata

# %%
adata.obs

# %%
adata.obs["sample_id"] = "GSM6058206"

# %%
adata.obs["dataset_id"] = "GSE147766"

# %%
adata.obs["diagnosis"] = "Neuroblastoma"

# %%
adata.var

# %%
adata.X

# %%
adata.layers["counts"] = adata.X.copy()

# %%
adata

# %%
# Write to h5ad format with compression
adata.write(str(DATA_ROOT / 'GSE147766/GSM6058206.h5ad'), compression='gzip')

# %%
gc.collect()
