# %%
import os
from pathlib import Path

DATA_ROOT = Path(os.environ.get('B_CELL_ATLAS_DATA', 'data'))

# !ls

# %% [markdown]
# Creating h5ad files from 10x Data
# use singlec env

# %%
import anndata as ad
import os
import gc 
import scanpy as sc
import pandas as pd

# %%
import scanpy as sc

# read directly from directory
adata = sc.read_10x_mtx(
    path=str(DATA_ROOT / 'GSE236351'),
    var_names='gene_symbols',
    cache=True, prefix = "GSM7528331_M7_"
)

# %%
adata

# %%
adata.obs

# %%
adata.var

# %%
adata.obs["sample_id"] = "GSM7528331"
adata.obs["dataset_id"] = "GSE236351"
adata.obs["diagnosis"] = "MPAL"

# %%
adata.layers["counts"] = adata.X.copy()

# %%
adata

# %%
adata.obs

# %%
# Write to h5ad format with compression
adata.write(str(DATA_ROOT / 'GSE236351/GSM7528331.h5ad'), compression='gzip')

# %%
gc.collect()
