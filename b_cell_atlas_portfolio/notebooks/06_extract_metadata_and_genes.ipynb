# %% [markdown]
# Extracting the adata.var and adata.obs from the adata object and saving them as csv files

# %%
import anndata as ad

# Load only the .var attribute of the AnnData object
adata = ad.read_h5ad(str(DATA_ROOT / "intermediate" / "merged_atlas.h5ad"), backed="r")  # Open in read-only mode
adata.var.to_csv(str(DATA_ROOT / "intermediate" / "merged_atlas_var.csv"), index=True)  # Save to CSV

# %%
adata.obs_names_make_unique()
adata.obs.to_csv(str(DATA_ROOT / "intermediate" / "merged_atlas_obs.csv"), index=True)

# %%
import pandas as pd
obs = pd.read_csv(str(DATA_ROOT / "intermediate" / "merged_atlas_obs.csv"))

# %%
obs.head()

# %%
adata.var

# %%
import gc
gc.collect()
